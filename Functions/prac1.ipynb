# %% [markdown]
# Celsius To Fahrenheit
# Instructions
# Problem Description:
#
# You are given a temperature in Celsius. Your task is to convert it to Fahrenheit and return the result.
#
# Formula:
#
# To convert Celsius to Fahrenheit, use the formula:
#
# F = (9/5 * C) + 32
#
# Where F is the temperature in Fahrenheit and C is the temperature in Celsius.

# %%
def conversion_celius_franheit(cel):
    f=0
    f=int(9/5 * cel)+32
    return f

celsius=float(input("enter the temperature in celsius"))
conversion_celius_franheit((celsius))
# Out:
# 98

# %% [markdown]
# Area of a Rectangle
# Instructions
# Problem Description:
#
# You are given the length and breadth of a rectangle. Your task is to compute and return the area of the rectangle.
#
# Formula:
#
# To calculate the area of a rectangle:
#
# Area=length×breadth

# %%
def area_of_rectangle(lent,bread):
    return lent*bread

area_of_rectangle(3,4)
# Out:
# 12

# %% [markdown]
# Distance Covered by a Vehicle
# Instructions
# Problem Description:
#
# You are given the speed of a vehicle and the time it has traveled. Your task is to compute and return the distance traveled by the vehicle.
#
# Formula:
#
# To calculate the distance traveled by a vehicle:
#
# Distance=Speed×Time

# %%
def distance_traveled_by_veh(speead,time):
    return speed*time

speed=float(input("enter speed of a vehicle"))
time=float(input("enter time of a vehcle"))
distance_traveled_by_veh(speed,time)
# Out:
# 40.0

# %% [markdown]
# Number of Rounds of Lift
# Instructions
# Problem Description:
#
# You are given n, the total number of people, and capacity, the maximum number of people the lift can carry at a time. All people want to go from the ground floor to the top floor. Your task is to calculate the number of rounds the lift has to make to transport all the people to the top floor.

# %%
def number_of_rounds_lift_makes(n,m):
    return n/m

total_number_of_people_n=25
maximum_number_of_people_lift_carries=10
number_of_rounds_lift_makes(total_number_of_people_n,maximum_number_of_people_lift_carries)
# Out:
# 2.5

# %% [markdown]
# Line Equation
# Instructions
# Problem Description:
#
# You are given the slope m and the y-intercept b of a line, along with a value x. Your task is to calculate and return the value of y using the equation of a line in slope-intercept form:
#
# y=mx+b

# %%
def calculate_y(m, b, x):
    y = m * x + b
    return y

# Example usage:
slope = 2.5
y_intercept = 3.0
x_value = 4.0

calculated_y = calculate_y(slope, y_intercept, x_value)
print(f"For the equation y = {slope}x + {y_intercept}, when x is {x_value}, y is {calculated_y}")
# Out:
# For the equation y = 2.5x + 3.0, when x is 4.0, y is 13.0
